# %% [markdown]
# <a href="https://colab.research.google.com/github/Esandu-Meth-Obadaarachchi/LibraryManagementSystem/blob/main/mat_not_working_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from IPython.display import HTML

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS=3
EPOCHS=50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/dsgp dataset/tea sickness dataset",
    seed=123,
    shuffle = True,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
class_names = dataset.class_names
class_names
# Out:
# Found 885 files belonging to 8 classes.
# ['Anthracnose',
#  'algal leaf',
#  'bird eye spot',
#  'brown blight',
#  'gray light',
#  'healthy',
#  'red leaf spot',
#  'white spot']

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 256, 256, 3)
# [0 6 6 2 2 5 4 7 5 2 3 2 7 1 3 6 2 5 7 1 7 6 7 6 7 0 2 2 1 2 7 3]

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
len(dataset)
train_size = 0.8
len(dataset)*train_size
# Out:
# 22.400000000000002

# %%
train_ds = dataset.take(54)
len(train_ds)
# Out:
# 28

# %%
test_ds = dataset.skip(54)
len(test_ds)
# Out:
# 0

# %%
val_size=0.1
len(dataset)*val_size
# Out:
# 2.8000000000000003

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 0

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 0

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1

    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
len(val_ds)
len(test_ds)
# Out:
# 4

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.2),
    layers.experimental.preprocessing.RandomContrast(0.2),
    layers.experimental.preprocessing.RandomTranslation(0.2, 0.2)
])

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout

input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 8

# using TensorFlow's Rescaling layer
resize_and_rescale = layers.Rescaling(1./255, input_shape=input_shape)

model = models.Sequential([
    resize_and_rescale,

    layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(256, kernel_size=(3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(512, kernel_size=(3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),

    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),  # Adding dropout for regularization

    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),

    layers.Flatten(),

    layers.Dense(n_classes, activation='softmax'),
])

model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_18 (Conv2D)          (None, 254, 254, 32)      896
#
#  batch_normalization (Batch  (None, 254, 254, 32)      128
#  Normalization)
#
#  max_pooling2d_18 (MaxPooli  (None, 127, 127, 32)      0
#  ng2D)
#
#  conv2d_19 (Conv2D)          (None, 125, 125, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 125, 125, 64)      256
#  chNormalization)
#
#  max_pooling2d_19 (MaxPooli  (None, 62, 62, 64)        0
#  ng2D)
#
#  conv2d_20 (Conv2D)          (None, 60, 60, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 60, 60, 128)       512
#  chNormalization)
#
#  max_pooling2d_20 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 256)       295168
#
#  batch_normalization_3 (Bat  (None, 28, 28, 256)       1024
#  chNormalization)
#
#  max_pooling2d_21 (MaxPooli  (None, 14, 14, 256)       0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 12, 12, 512)       1180160
#
#  batch_normalization_4 (Bat  (None, 12, 12, 512)       2048
#  chNormalization)
#
#  max_pooling2d_22 (MaxPooli  (None, 6, 6, 512)         0
#  ng2D)
#
#  flatten_3 (Flatten)         (None, 18432)             0
#
#  dense_6 (Dense)             (None, 512)               9437696
#
#  batch_normalization_5 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  batch_normalization_6 (Bat  (None, 256)               1024
#  chNormalization)
#
#  flatten_4 (Flatten)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 11146696 (42.52 MB)
# Trainable params: 11143176 (42.51 MB)
# Non-trainable params: 3520 (13.75 KB)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=50,
)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 216s 10s/step - loss: 1.6137 - accuracy: 0.4343 - val_loss: 2.3915 - val_accuracy: 0.1406
# Epoch 2/50
# 22/22 [==============================] - 191s 9s/step - loss: 1.1238 - accuracy: 0.5584 - val_loss: 3.6025 - val_accuracy: 0.1406
# Epoch 3/50
# 22/22 [==============================] - 175s 8s/step - loss: 0.9095 - accuracy: 0.6234 - val_loss: 3.4397 - val_accuracy: 0.0938
# Epoch 4/50
# 22/22 [==============================] - 174s 8s/step - loss: 0.8857 - accuracy: 0.6219 - val_loss: 6.3234 - val_accuracy: 0.0938
# Epoch 5/50
# 22/22 [==============================] - 171s 8s/step - loss: 0.8242 - accuracy: 0.6710 - val_loss: 5.2715 - val_accuracy: 0.0938
# Epoch 6/50
# 22/22 [==============================] - 171s 8s/step - loss: 0.7349 - accuracy: 0.6955 - val_loss: 4.2769 - val_accuracy: 0.0625
# Epoch 7/50
# 22/22 [==============================] - 169s 8s/step - loss: 0.7096 - accuracy: 0.6840 - val_loss: 5.2161 - val_accuracy: 0.0938
# Epoch 8/50
# 22/22 [==============================] - 169s 8s/step - loss: 0.6551 - accuracy: 0.7172 - val_loss: 4.8609 - val_accuracy: 0.1875
# Epoch 9/50
# 22/22 [==============================] - 171s 8s/step - loss: 0.6423 - accuracy: 0.7157 - val_loss: 5.0756 - val_accuracy: 0.1875
# Epoch 10/50
# 22/22 [==============================] - 171s 8s/step - loss: 0.6875 - accuracy: 0.7157 - val_loss: 5.0957 - val_accuracy: 0.1875
# Epoch 11/50
# 22/22 [==============================] - 169s 8s/step - loss: 0.6149 - accuracy: 0.7359 - val_loss: 6.2436 - val_accuracy: 0.1875
# Epoch 12/50
# 22/22 [==============================] - 179s 8s/step - loss: 0.5638 - accuracy: 0.7619 - val_loss: 7.0104 - val_accuracy: 0.1875
# Epoch 13/50
# 22/22 [==============================] - 172s 8s/step - loss: 0.5436 - accuracy: 0.7605 - val_loss: 4.3212 - val_accuracy: 0.2344
# Epoch 14/50
# 22/22 [==============================] - 169s 8s/step - loss: 0.5567 - accuracy: 0.7547 - val_loss: 3.3311 - val_accuracy: 0.3281
# Epoch 15/50
# 22/22 [==============================] - 173s 8s/step - loss: 0.5061 - accuracy: 0.7850 - val_loss: 11.8534 - val_accuracy: 0.2188
# Epoch 16/50
# 22/22 [==============================] - 170s 8s/step - loss: 0.5546 - accuracy: 0.7835 - val_loss: 3.2490 - val_accuracy: 0.3594
# Epoch 17/50
# 22/22 [==============================] - 171s 8s/step - loss: 0.5962 - accuracy: 0.7489 - val_loss: 3.6931 - val_accuracy: 0.3281
# Epoch 18/50
# 22/22 [==============================] - 167s 8s/step - loss: 0.5126 - accuracy: 0.7763 - val_loss: 4.0183 - val_accuracy: 0.0781
# Epoch 19/50
# 22/22 [==============================] - 169s 8s/step - loss: 0.5314 - accuracy: 0.7749 - val_loss: 5.7072 - val_accuracy: 0.3438
# Epoch 20/50
# 22/22 [==============================] - 168s 8s/step - loss: 0.5002 - accuracy: 0.7821 - val_loss: 4.8583 - val_accuracy: 0.1875
# Epoch 21/50
# 22/22 [==============================] - 168s 8s/step - loss: 0.4865 - accuracy: 0.7922 - val_loss: 10.1670 - val_accuracy: 0.2500
# Epoch 22/50
# 22/22 [==============================] - 169s 8s/step - loss: 0.5053 - accuracy: 0.7778 - val_loss: 1.9024 - val_accuracy: 0.5469
# Epoch 23/50
# 22/22 [==============================] - 171s 8s/step - loss: 0.4944 - accuracy: 0.7994 - val_loss: 3.7156 - val_accuracy: 0.2812
# Epoch 24/50
# 22/22 [==============================] - 169s 8s/step - loss: 0.4156 - accuracy: 0.8326 - val_loss: 2.6955 - val_accuracy: 0.4375
# Epoch 25/50
# 22/22 [==============================] - 177s 8s/step - loss: 0.4513 - accuracy: 0.8268 - val_loss: 1.8409 - val_accuracy: 0.3594
# Epoch 26/50
# 22/22 [==============================] - 171s 8s/step - loss: 0.4143 - accuracy: 0.8326 - val_loss: 1.5694 - val_accuracy: 0.5156
# Epoch 27/50
# 22/22 [==============================] - 169s 8s/step - loss: 0.4147 - accuracy: 0.8312 - val_loss: 1.1078 - val_accuracy: 0.6406
# Epoch 28/50
# 22/22 [==============================] - 166s 7s/step - loss: 0.4163 - accuracy: 0.8398 - val_loss: 3.7142 - val_accuracy: 0.3594
# Epoch 29/50
# 22/22 [==============================] - 175s 8s/step - loss: 0.4109 - accuracy: 0.8312 - val_loss: 1.7899 - val_accuracy: 0.6250
# Epoch 30/50
# 22/22 [==============================] - 169s 8s/step - loss: 0.4574 - accuracy: 0.8196 - val_loss: 4.1326 - val_accuracy: 0.4062
# Epoch 31/50
# 22/22 [==============================] - 169s 8s/step - loss: 0.4156 - accuracy: 0.8283 - val_loss: 19.0751 - val_accuracy: 0.2344
# Epoch 32/50
# 22/22 [==============================] - 170s 8s/step - loss: 0.4921 - accuracy: 0.7864 - val_loss: 1.5653 - val_accuracy: 0.6094
# Epoch 33/50
# 22/22 [==============================] - 178s 8s/step - loss: 0.4540 - accuracy: 0.8009 - val_loss: 1.4509 - val_accuracy: 0.6094
# Epoch 34/50
# 22/22 [==============================] - 208s 9s/step - loss: 0.4166 - accuracy: 0.8196 - val_loss: 1.2134 - val_accuracy: 0.5469
# Epoch 35/50
# 22/22 [==============================] - 196s 9s/step - loss: 0.4079 - accuracy: 0.8196 - val_loss: 3.4105 - val_accuracy: 0.3906
# Epoch 36/50
# 22/22 [==============================] - 198s 9s/step - loss: 0.4209 - accuracy: 0.8384 - val_loss: 1.1190 - val_accuracy: 0.6875
# Epoch 37/50
# 22/22 [==============================] - 200s 9s/step - loss: 0.3931 - accuracy: 0.8355 - val_loss: 3.2162 - val_accuracy: 0.4062
# Epoch 38/50
# 22/22 [==============================] - 170s 8s/step - loss: 0.3798 - accuracy: 0.8413 - val_loss: 0.5755 - val_accuracy: 0.8125
# Epoch 39/50
# 22/22 [==============================] - 169s 8s/step - loss: 0.3538 - accuracy: 0.8485 - val_loss: 0.9733 - val_accuracy: 0.6406
# Epoch 40/50
# 22/22 [==============================] - 196s 9s/step - loss: 0.3969 - accuracy: 0.8384 - val_loss: 2.3414 - val_accuracy: 0.4062
# Epoch 41/50
# 22/22 [==============================] - 177s 8s/step - loss: 0.3623 - accuracy: 0.8571 - val_loss: 5.6127 - val_accuracy: 0.3594
# Epoch 42/50
# 22/22 [==============================] - 175s 8s/step - loss: 0.3590 - accuracy: 0.8514 - val_loss: 1.9248 - val_accuracy: 0.5156
# Epoch 43/50
# 22/22 [==============================] - 168s 8s/step - loss: 0.3766 - accuracy: 0.8586 - val_loss: 4.4563 - val_accuracy: 0.2656
# Epoch 44/50
# 22/22 [==============================] - 178s 8s/step - loss: 0.3630 - accuracy: 0.8571 - val_loss: 2.2138 - val_accuracy: 0.5938
# Epoch 45/50
# 22/22 [==============================] - 172s 8s/step - loss: 0.3580 - accuracy: 0.8557 - val_loss: 1.5640 - val_accuracy: 0.5469
# Epoch 46/50
# 22/22 [==============================] - 170s 8s/step - loss: 0.3490 - accuracy: 0.8485 - val_loss: 1.9216 - val_accuracy: 0.5625
# Epoch 47/50
# 22/22 [==============================] - 171s 8s/step - loss: 0.3277 - accuracy: 0.8600 - val_loss: 2.5258 - val_accuracy: 0.5938
# Epoch 48/50
# 22/22 [==============================] - 172s 8s/step - loss: 0.3284 - accuracy: 0.8701 - val_loss: 0.7678 - val_accuracy: 0.7656
# Epoch 49/50
# 22/22 [==============================] - 169s 8s/step - loss: 0.3327 - accuracy: 0.8514 - val_loss: 5.7247 - val_accuracy: 0.3438
# Epoch 50/50
# 22/22 [==============================] - 174s 8s/step - loss: 0.3731 - accuracy: 0.8442 - val_loss: 1.0842 - val_accuracy: 0.6406

# %%
scores = model.evaluate(test_ds)
# Out:
# 4/4 [==============================] - 9s 2s/step - loss: 1.0541 - accuracy: 0.6953

# %%
scores
# Out:
# [1.0540640354156494, 0.6953125]

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 50, 'steps': 22}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
type(history.history['loss'])
# Out:
# list

# %%
len(history.history['loss'])
# Out:
# 50

# %%
history.history['loss'][:5] # show loss for first 5 epochs
# Out:
# [1.6136571168899536,
#  1.1237856149673462,
#  0.9095053672790527,
#  0.885736882686615,
#  0.8241684436798096]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: gray light
# 1/1 [==============================] - 4s 4s/step
# predicted label: gray light

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 119ms/step

# %%
import os
from keras.models import load_model

# Replace 'model' with the name of your model
model_name = 'model4'

# Path to your Google Drive
drive_path = "/content/drive/MyDrive/colab_NoteBooks"

# Full path for saving the model
save_path = f"{drive_path}/{model_name}"

# Save the model
model.save(save_path)
