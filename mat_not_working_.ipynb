# %% [markdown]
# <a href="https://colab.research.google.com/github/Esandu-Meth-Obadaarachchi/LibraryManagementSystem/blob/main/mat_not_working_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from IPython.display import HTML

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS=3
EPOCHS=50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/dsgp dataset/tea sickness dataset",
    seed=123,
    shuffle = True,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
class_names = dataset.class_names
class_names
# Out:
# Found 885 files belonging to 8 classes.
# ['Anthracnose',
#  'algal leaf',
#  'bird eye spot',
#  'brown blight',
#  'gray light',
#  'healthy',
#  'red leaf spot',
#  'white spot']

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 256, 256, 3)
# [0 6 6 2 2 5 4 7 5 2 3 2 7 1 3 6 2 5 7 1 7 6 7 6 7 0 2 2 1 2 7 3]

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
len(dataset)
train_size = 0.8
len(dataset)*train_size
# Out:
# 22.400000000000002

# %%
train_ds = dataset.take(54)
len(train_ds)
# Out:
# 28

# %%
test_ds = dataset.skip(54)
len(test_ds)
# Out:
# 0

# %%
val_size=0.1
len(dataset)*val_size
# Out:
# 2.8000000000000003

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 0

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 0

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1

    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
len(val_ds)
len(test_ds)
# Out:
# 4

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.2),
    layers.experimental.preprocessing.RandomContrast(0.2),
    layers.experimental.preprocessing.RandomTranslation(0.2, 0.2)
])

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 8

# Assuming you're using TensorFlow's Rescaling layer
resize_and_rescale = layers.Rescaling(1./255, input_shape=input_shape)

model = models.Sequential([
    resize_and_rescale,

    layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(256, kernel_size=(3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(512, kernel_size=(3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),

    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),  # Adding dropout for regularization

    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),

    layers.Flatten(),

    layers.Dense(n_classes, activation='softmax'),
])

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_5 (Conv2D)           (None, 254, 254, 32)      896
#
#  batch_normalization_7 (Bat  (None, 254, 254, 32)      128
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 127, 127, 32)      0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 125, 125, 64)      18496
#
#  batch_normalization_8 (Bat  (None, 125, 125, 64)      256
#  chNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 62, 62, 64)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 60, 60, 128)       73856
#
#  batch_normalization_9 (Bat  (None, 60, 60, 128)       512
#  chNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 30, 30, 128)       0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 256)       295168
#
#  batch_normalization_10 (Ba  (None, 28, 28, 256)       1024
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 14, 14, 256)       0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 12, 12, 512)       1180160
#
#  batch_normalization_11 (Ba  (None, 12, 12, 512)       2048
#  tchNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 6, 6, 512)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 18432)             0
#
#  dense_3 (Dense)             (None, 512)               9437696
#
#  batch_normalization_12 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  batch_normalization_13 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  flatten_3 (Flatten)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 11146696 (42.52 MB)
# Trainable params: 11143176 (42.51 MB)
# Non-trainable params: 3520 (13.75 KB)
# _________________________________________________________________

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=50,
)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 176s 8s/step - loss: 1.5160 - accuracy: 0.4675 - val_loss: 3.2728 - val_accuracy: 0.0938
# Epoch 2/50
# 22/22 [==============================] - 172s 8s/step - loss: 0.9832 - accuracy: 0.6089 - val_loss: 6.1391 - val_accuracy: 0.0938
# Epoch 3/50
# 22/22 [==============================] - 171s 8s/step - loss: 0.8949 - accuracy: 0.6248 - val_loss: 5.4777 - val_accuracy: 0.1875
# Epoch 4/50
# 22/22 [==============================] - 172s 8s/step - loss: 0.7800 - accuracy: 0.6753 - val_loss: 5.8747 - val_accuracy: 0.1562
# Epoch 5/50
# 22/22 [==============================] - 168s 8s/step - loss: 0.7515 - accuracy: 0.6999 - val_loss: 6.8719 - val_accuracy: 0.1562
# Epoch 6/50
# 22/22 [==============================] - 166s 7s/step - loss: 0.6656 - accuracy: 0.7027 - val_loss: 6.7426 - val_accuracy: 0.1875
# Epoch 7/50
# 22/22 [==============================] - 168s 8s/step - loss: 0.6889 - accuracy: 0.7013 - val_loss: 7.5522 - val_accuracy: 0.1875
# Epoch 8/50
# 22/22 [==============================] - 166s 8s/step - loss: 0.6580 - accuracy: 0.7258 - val_loss: 7.5402 - val_accuracy: 0.1875
# Epoch 9/50
# 22/22 [==============================] - 167s 8s/step - loss: 0.5996 - accuracy: 0.7489 - val_loss: 6.8199 - val_accuracy: 0.1875
# Epoch 10/50
# 22/22 [==============================] - 166s 7s/step - loss: 0.6218 - accuracy: 0.7417 - val_loss: 4.9546 - val_accuracy: 0.1875
# Epoch 11/50
# 22/22 [==============================] - 166s 8s/step - loss: 0.5320 - accuracy: 0.7691 - val_loss: 7.3188 - val_accuracy: 0.0938
# Epoch 12/50
# 22/22 [==============================] - 167s 8s/step - loss: 0.6007 - accuracy: 0.7475 - val_loss: 5.7252 - val_accuracy: 0.1719
# Epoch 13/50
# 22/22 [==============================] - 165s 7s/step - loss: 0.5854 - accuracy: 0.7417 - val_loss: 6.6332 - val_accuracy: 0.1562
# Epoch 14/50
# 22/22 [==============================] - 167s 8s/step - loss: 0.5148 - accuracy: 0.7648 - val_loss: 4.0378 - val_accuracy: 0.3125
# Epoch 15/50
# 22/22 [==============================] - 166s 7s/step - loss: 0.4527 - accuracy: 0.8052 - val_loss: 4.5645 - val_accuracy: 0.2969
# Epoch 16/50
# 22/22 [==============================] - 168s 8s/step - loss: 0.4834 - accuracy: 0.7908 - val_loss: 5.5699 - val_accuracy: 0.2031
# Epoch 17/50
# 22/22 [==============================] - 165s 8s/step - loss: 0.5559 - accuracy: 0.7648 - val_loss: 5.0834 - val_accuracy: 0.1406
# Epoch 18/50
# 22/22 [==============================] - 165s 7s/step - loss: 0.5146 - accuracy: 0.7879 - val_loss: 4.1136 - val_accuracy: 0.3281
# Epoch 19/50
# 22/22 [==============================] - 167s 8s/step - loss: 0.4474 - accuracy: 0.8167 - val_loss: 3.1697 - val_accuracy: 0.3906
# Epoch 20/50
# 22/22 [==============================] - 167s 8s/step - loss: 0.4828 - accuracy: 0.7994 - val_loss: 2.0136 - val_accuracy: 0.5469
# Epoch 21/50
# 22/22 [==============================] - 167s 8s/step - loss: 0.4520 - accuracy: 0.8167 - val_loss: 5.2162 - val_accuracy: 0.2188
# Epoch 22/50
# 22/22 [==============================] - 166s 7s/step - loss: 0.4827 - accuracy: 0.7994 - val_loss: 9.6954 - val_accuracy: 0.1562
# Epoch 23/50
# 22/22 [==============================] - 168s 8s/step - loss: 0.4644 - accuracy: 0.8038 - val_loss: 2.9044 - val_accuracy: 0.3281
# Epoch 24/50
# 22/22 [==============================] - 163s 7s/step - loss: 0.4790 - accuracy: 0.8153 - val_loss: 7.0203 - val_accuracy: 0.2344
# Epoch 25/50
# 22/22 [==============================] - 166s 7s/step - loss: 0.4811 - accuracy: 0.8009 - val_loss: 4.4724 - val_accuracy: 0.2656
# Epoch 26/50
# 22/22 [==============================] - 165s 8s/step - loss: 0.4507 - accuracy: 0.8052 - val_loss: 2.8519 - val_accuracy: 0.2500
# Epoch 27/50
# 22/22 [==============================] - 167s 8s/step - loss: 0.3774 - accuracy: 0.8384 - val_loss: 3.2979 - val_accuracy: 0.4062
# Epoch 28/50
# 22/22 [==============================] - 165s 8s/step - loss: 0.3836 - accuracy: 0.8355 - val_loss: 32.0861 - val_accuracy: 0.1406
# Epoch 29/50
# 22/22 [==============================] - 167s 8s/step - loss: 0.4284 - accuracy: 0.8225 - val_loss: 18.1182 - val_accuracy: 0.2344
# Epoch 30/50
# 22/22 [==============================] - 167s 8s/step - loss: 0.4064 - accuracy: 0.8312 - val_loss: 11.1195 - val_accuracy: 0.2344
# Epoch 31/50
# 22/22 [==============================] - 167s 8s/step - loss: 0.4849 - accuracy: 0.7994 - val_loss: 20.6207 - val_accuracy: 0.2344
# Epoch 32/50
# 22/22 [==============================] - 166s 8s/step - loss: 0.4028 - accuracy: 0.8413 - val_loss: 4.4266 - val_accuracy: 0.3594
# Epoch 33/50
# 22/22 [==============================] - 166s 8s/step - loss: 0.4038 - accuracy: 0.8153 - val_loss: 4.0576 - val_accuracy: 0.4531
# Epoch 34/50
# 22/22 [==============================] - 166s 8s/step - loss: 0.3950 - accuracy: 0.8283 - val_loss: 9.8568 - val_accuracy: 0.2344
# Epoch 35/50
# 22/22 [==============================] - 167s 8s/step - loss: 0.3932 - accuracy: 0.8427 - val_loss: 4.6622 - val_accuracy: 0.3125
# Epoch 36/50
# 22/22 [==============================] - 168s 8s/step - loss: 0.3786 - accuracy: 0.8514 - val_loss: 5.9179 - val_accuracy: 0.2656
# Epoch 37/50
# 22/22 [==============================] - 168s 8s/step - loss: 0.3555 - accuracy: 0.8644 - val_loss: 1.5058 - val_accuracy: 0.6094
# Epoch 38/50
# 22/22 [==============================] - 166s 8s/step - loss: 0.3942 - accuracy: 0.8240 - val_loss: 1.4555 - val_accuracy: 0.5625
# Epoch 39/50
# 22/22 [==============================] - 166s 8s/step - loss: 0.3985 - accuracy: 0.8442 - val_loss: 6.4644 - val_accuracy: 0.2656
# Epoch 40/50
# 22/22 [==============================] - 166s 7s/step - loss: 0.3515 - accuracy: 0.8543 - val_loss: 1.7126 - val_accuracy: 0.6719
# Epoch 41/50
# 22/22 [==============================] - 168s 8s/step - loss: 0.3489 - accuracy: 0.8470 - val_loss: 2.4195 - val_accuracy: 0.4375
# Epoch 42/50
# 22/22 [==============================] - 165s 8s/step - loss: 0.3378 - accuracy: 0.8571 - val_loss: 0.3914 - val_accuracy: 0.8438
# Epoch 43/50
# 22/22 [==============================] - 166s 8s/step - loss: 0.2954 - accuracy: 0.8903 - val_loss: 2.0475 - val_accuracy: 0.5625
# Epoch 44/50
# 22/22 [==============================] - 165s 7s/step - loss: 0.3445 - accuracy: 0.8615 - val_loss: 1.9438 - val_accuracy: 0.6406
# Epoch 45/50
# 22/22 [==============================] - 165s 8s/step - loss: 0.3774 - accuracy: 0.8398 - val_loss: 1.0135 - val_accuracy: 0.6406
# Epoch 46/50
# 22/22 [==============================] - 167s 8s/step - loss: 0.3331 - accuracy: 0.8672 - val_loss: 3.9341 - val_accuracy: 0.3281
# Epoch 47/50
# 22/22 [==============================] - 164s 7s/step - loss: 0.3585 - accuracy: 0.8571 - val_loss: 1.3877 - val_accuracy: 0.5625
# Epoch 48/50
# 22/22 [==============================] - 168s 8s/step - loss: 0.3482 - accuracy: 0.8528 - val_loss: 8.3523 - val_accuracy: 0.3906
# Epoch 49/50
# 22/22 [==============================] - 166s 8s/step - loss: 0.3031 - accuracy: 0.8701 - val_loss: 1.4348 - val_accuracy: 0.6250
# Epoch 50/50
# 22/22 [==============================] - 166s 8s/step - loss: 0.3510 - accuracy: 0.8514 - val_loss: 4.0345 - val_accuracy: 0.3906

# %%
scores = model.evaluate(test_ds)
# Out:
# 4/4 [==============================] - 13s 3s/step - loss: 3.3529 - accuracy: 0.5156

# %%
scores
# Out:
# [3.352881669998169, 0.515625]

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 50, 'steps': 22}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
type(history.history['loss'])
# Out:
# list

# %%
len(history.history['loss'])
# Out:
# 50

# %%
history.history['loss'][:5] # show loss for first 5 epochs
# Out:
# [1.5160197019577026,
#  0.9831671714782715,
#  0.8948866128921509,
#  0.7800018787384033,
#  0.7514772415161133]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: red leaf spot
# 1/1 [==============================] - 3s 3s/step
# predicted label: healthy

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 267ms/step

# %%
import os
from keras.models import load_model

# Replace 'model' with the name of your model
model_name = 'model3'

# Path to your Google Drive
drive_path = "/content/drive/MyDrive/colab_NoteBooks"

# Full path for saving the model
save_path = os.path.join(drive_path, model_name)

# Save the model
model.save(save_path)
